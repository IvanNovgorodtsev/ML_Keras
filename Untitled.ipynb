# %%
import pandas as pd
import numpy as np
from keras import optimizers
from sklearn import model_selection
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Using TensorFlow backend.

# %%
# kind of preprocess
df = pd.read_csv("train_2v.csv", nrows=1000)
df = df.drop('id', 1)

df.ever_married = pd.Series(np.where(df.ever_married == 'Yes', 1, 0), df.index)
df.gender = pd.Series(np.where(df.gender == 'Male', 1, 0), df.index)

dff = pd.get_dummies(data=df, columns=['work_type', 'Residence_type','smoking_status'])

dff = dff.dropna()

X = dff.drop(['stroke'], axis = 1)
y = dff.stroke.values

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size = 0.2, random_state=0)

# %%
sns.catplot(x='ever_married',kind='count',col='stroke',data=df)
sns.catplot(x='work_type',kind='count',col='stroke',data=df)
sns.catplot(x='smoking_status',kind='count',col='stroke',data=df)
#sns.catplot(x='age',kind='count',data=df)

g = sns.catplot(x='age',kind='count',data=df)
g.fig.set_figwidth(25)
g.fig.set_figheight(5)
print(g)
# Out:
# <seaborn.axisgrid.FacetGrid object at 0x00000184D990A7F0>

# %%
sns.distplot(df.loc[df['stroke'] == 0]['age'],kde=False, norm_hist=True, bins=20)
sns.distplot(df.loc[df['stroke'] == 1]['age'],kde=False, norm_hist=True, bins=20)

#sns.distplot(df.loc[df['stroke'] == 0]['bmi'],kde=False, norm_hist=True, bins=20)
#sns.distplot(df.loc[df['stroke'] == 1]['bmi'],kde=False, norm_hist=True, bins=20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-15f409d664b8> in <module>
#       2 sns.distplot(df.loc[df['stroke'] == 1]['age'],kde=False, norm_hist=True, bins=20)
#       3
# ----> 4 sns.distplot(df.loc[df['stroke'] == 0]['bmi'],kde=False, norm_hist=True, bins=20)
#       5 sns.distplot(df.loc[df['stroke'] == 1]['bmi'],kde=False, norm_hist=True, bins=20)
#
# c:\python36\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     223         hist_color = hist_kws.pop("color", color)
#     224         ax.hist(a, bins, orientation=orientation,
# --> 225                 color=hist_color, **hist_kws)
#     226         if hist_color != color:
#     227             hist_kws["color"] = hist_color
#
# c:\python36\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# c:\python36\lib\site-packages\matplotlib\axes\_axes.py in hist(***failed resolving arguments***)
#    6637             # this will automatically overwrite bins,
#    6638             # so that each histogram uses the same bins
# -> 6639             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6640             m = m.astype(float)  # causes problems later if it's an int
#    6641             if mlast is None:
#
# <__array_function__ internals> in histogram(*args, **kwargs)
#
# c:\python36\lib\site-packages\numpy\lib\histograms.py in histogram(a, bins, range, normed, weights, density)
#     783     a, weights = _ravel_and_check_weights(a, weights)
#     784
# --> 785     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     786
#     787     # Histogram is an integer or a float array depending on the weights.
#
# c:\python36\lib\site-packages\numpy\lib\histograms.py in _get_bin_edges(a, bins, range, weights)
#     417             raise ValueError('`bins` must be positive, when an integer')
#     418
# --> 419         first_edge, last_edge = _get_outer_edges(a, range)
#     420
#     421     elif np.ndim(bins) == 1:
#
# c:\python36\lib\site-packages\numpy\lib\histograms.py in _get_outer_edges(a, range)
#     304         if first_edge > last_edge:
#     305             raise ValueError(
# --> 306                 'max must be larger than min in range parameter.')
#     307         if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
#     308             raise ValueError(
#
# ValueError: max must be larger than min in range parameter.
